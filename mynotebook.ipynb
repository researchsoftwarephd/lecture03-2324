# %% [markdown]
# ## This is a header
#
# Hello!

# %%
from mymodule import load_and_rotate
import matplotlib.pyplot as plt

# %%
img = load_and_rotate('pisco.jpg')

plt.imshow(img)

# %%
img = load_and_rotate('firefox.png')

display(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512>
